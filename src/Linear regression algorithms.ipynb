# %% [markdown]
# <h1>Linear regression algorithms.<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Linear-regression" data-toc-modified-id="Linear-regression-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Linear regression</a></span><ul class="toc-item"><li><span><a href="#Hypothesis" data-toc-modified-id="Hypothesis-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Hypothesis</a></span></li><li><span><a href="#Cost-function---Mean-squared-error" data-toc-modified-id="Cost-function---Mean-squared-error-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Cost function - Mean squared error</a></span></li><li><span><a href="#Gradient-descent" data-toc-modified-id="Gradient-descent-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Gradient descent</a></span></li><li><span><a href="#Feature-scaling-and-mean-normalization" data-toc-modified-id="Feature-scaling-and-mean-normalization-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Feature scaling and mean normalization</a></span></li><li><span><a href="#Normal-equation" data-toc-modified-id="Normal-equation-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Normal equation</a></span></li><li><span><a href="#Learning-rate-decay" data-toc-modified-id="Learning-rate-decay-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Learning rate decay</a></span></li></ul></li><li><span><a href="#Linear-regression-implementations" data-toc-modified-id="Linear-regression-implementations-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Linear regression implementations</a></span><ul class="toc-item"><li><span><a href="#Mean-squared-error" data-toc-modified-id="Mean-squared-error-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Mean squared error</a></span></li><li><span><a href="#Gradient-descent" data-toc-modified-id="Gradient-descent-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Gradient descent</a></span></li><li><span><a href="#Feature-normalization" data-toc-modified-id="Feature-normalization-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Feature normalization</a></span></li><li><span><a href="#Normal-equation-implementation" data-toc-modified-id="Normal-equation-implementation-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Normal equation implementation</a></span></li><li><span><a href="#Gradient-descent-with-learning-rate-decay" data-toc-modified-id="Gradient-descent-with-learning-rate-decay-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Gradient descent with learning rate decay</a></span></li></ul></li><li><span><a href="#Linear-regression-examples" data-toc-modified-id="Linear-regression-examples-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Linear regression examples</a></span><ul class="toc-item"><li><span><a href="#Plot-hypothesis" data-toc-modified-id="Plot-hypothesis-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Plot hypothesis</a></span></li><li><span><a href="#Plot-different-hypothesis-and-mean-squared-error-values" data-toc-modified-id="Plot-different-hypothesis-and-mean-squared-error-values-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Plot different hypothesis and mean squared error values</a></span></li><li><span><a href="#Plot-mean-squared-error-for-univariable-hypothesis" data-toc-modified-id="Plot-mean-squared-error-for-univariable-hypothesis-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Plot mean squared error for univariable hypothesis</a></span></li><li><span><a href="#Plot-mean-squared-error-for-multivariable-hypothesis" data-toc-modified-id="Plot-mean-squared-error-for-multivariable-hypothesis-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Plot mean squared error for multivariable hypothesis</a></span></li><li><span><a href="#Plot-cost-function-for-univariable-hypothesis" data-toc-modified-id="Plot-cost-function-for-univariable-hypothesis-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Plot cost function for univariable hypothesis</a></span></li><li><span><a href="#Plot-cost-function-for-multivariable-hypothesis" data-toc-modified-id="Plot-cost-function-for-multivariable-hypothesis-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Plot cost function for multivariable hypothesis</a></span></li><li><span><a href="#Plot-cost-function-for-different-learning-rates-I" data-toc-modified-id="Plot-cost-function-for-different-learning-rates-I-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Plot cost function for different learning rates I</a></span></li><li><span><a href="#Plot-cost-function-for-differen-learning-rates-II" data-toc-modified-id="Plot-cost-function-for-differen-learning-rates-II-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Plot cost function for differen learning rates II</a></span></li><li><span><a href="#Plot-hypothesis-and-cost-function" data-toc-modified-id="Plot-hypothesis-and-cost-function-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Plot hypothesis and cost function</a></span></li><li><span><a href="#Plot-normalized-features" data-toc-modified-id="Plot-normalized-features-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Plot normalized features</a></span></li><li><span><a href="#Calculate-hypothesis-for-noralized-features" data-toc-modified-id="Calculate-hypothesis-for-noralized-features-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Calculate hypothesis for noralized features</a></span></li><li><span><a href="#Calculate-hypothesis-using-normal-equation" data-toc-modified-id="Calculate-hypothesis-using-normal-equation-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>Calculate hypothesis using normal equation</a></span></li><li><span><a href="#Comparing-gradient-descent-with-and-without-learning-rate-decay" data-toc-modified-id="Comparing-gradient-descent-with-and-without-learning-rate-decay-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>Comparing gradient descent with and without learning rate decay</a></span></li><li><span><a href="#Plot-hypothesis-using-different-functions" data-toc-modified-id="Plot-hypothesis-using-different-functions-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span>Plot hypothesis using different functions</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Linear regression

# %% [markdown]
# n - number of features <br>
# m - number of training examples <br>
# $x^{(i)}$ - $i^{th}$ input variable <br>
# $y^{(i)}$ - $i^{th}$ output variable <br>
# $X$ - input set <br>
# &emsp; $X=\begin{bmatrix} (x^{(1)})^T \\ (x^{(2)})^T \\ \vdots  \\ (x^{(m)})^T \end{bmatrix}$

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# Parameters: <br>
# &emsp; $\theta_0, \theta_1,...\theta_n = \theta$ <br><br>
# Hypothesis: <br>
# &emsp; $h_\theta(x) = \theta_0x_0+\theta_1x_1+...+\theta_nx_n = \theta^Tx$ &emsp; for $x_0=1$<br><br>
# Vectorized hypothesis: <br>
# &emsp; $y_{predicted} = X\theta$

# %% [markdown]
# ## Cost function - Mean squared error

# %% [markdown]
# Cost function: <br>
# &emsp; $J(\theta) = \frac{1}{2m} \sum \limits _{i=1} ^m (h_\theta(x^{(i)})-y^{(i)})^2$ <br><br>
# Vectorized cost function: <br>
# &emsp; $J(\theta) = \frac{1}{2m}(X\theta - y)^T(X\theta - y)$

# %% [markdown]
# ## Gradient descent

# %% [markdown]
# $\alpha$ - learning rate <br><br>
# Gradient descent algorithm: <br>
# &emsp; $\theta_j := \theta_j - \alpha \frac{\partial}{\partial\theta_j}J(\theta)$ <br>
# &emsp;$\theta_j := \theta_j - \alpha \frac{1}{m} \sum \limits _{i=1} ^m (h_\theta(x^{(i)})-y^{(i)})x_j^{(i)}$ &emsp; for j=0...n,  $x_0=1$ <br><br>
# Vectorized gradient descent: <br>
# &emsp; $\theta = \theta - \alpha \frac{1}{m} ((X\theta - y)^T X)^T = \theta - \alpha \frac{1}{m} X^T (X\theta - y)$

# %% [markdown]
# ## Feature scaling and mean normalization

# %% [markdown]
# $\mu_i$ - mean <br>
# $\sigma_i$ - standard deviation <br><br>
# Feature scaling and mean normalization: <br>
# &emsp; $x_i = \frac{x_i - \mu_i}{\sigma_i}$ <br><br>
# Vectorized feature scaling and mean normalization: <br>
# &emsp; $\mu \in \mathbb{R^n}$ <br>
# &emsp; $\sigma \in \mathbb{R^n}$ <br>
# &emsp; $t \in \mathbb{1}^m$ <br><br>
# &emsp; $X_{normalize} = (X - t\mu^T) \oslash (t\sigma^T)$

# %% [markdown]
# ## Normal equation

# %% [markdown]
# min of $J(\theta) = \frac{\partial}{\partial\theta}J(\theta) = \frac{\partial}{\partial\theta} \frac{1}{2m} \sum \limits _{i=1} ^m (h_\theta(x^{(i)})-y^{(i)})^2 = 0 => \theta = (X^TX)^{-1}X^Ty$ <br>

# %% [markdown]
# ## Learning rate decay

# %% [markdown]
# $\eta = \eta * \frac{1}{1 + decay\_rate * epoch}$

# %% [markdown]
# # Linear regression implementations

# %% [markdown]
# ## Mean squared error

# %%
def mean_squared_error(X, y, theta):
    m = X.shape[0]
    J = (1 / (2 * m)) * ((X @ theta - y).T @ (X @ theta - y))
    return J[0][0]

# %% [markdown]
# ## Gradient descent

# %%
def gradient_descent(X, y, theta, alpha):
    m = X.shape[0]
    return theta - (alpha / m) * X.T @ (X @ theta - y)

# %% [markdown]
# ## Feature normalization

# %%
def feature_normalize(X):
    mu = np.array([np.mean(X, axis=0)])
    sigma = np.array([np.std(X, axis=0)])
    t = np.ones((X.shape[0], 1))
    X_norm = (X - t @ mu) / (t @ sigma)
    return X_norm, mu, sigma

# %% [markdown]
# ## Normal equation implementation

# %%
def normal_equation(X, y):
    return np.linalg.inv(X.T @ X) @ (X.T @ y)

# %% [markdown]
# ## Gradient descent with learning rate decay

# %%
def decay_learning_rate(eta, decay_rate, epoch):
    return eta*(1/(1+decay_rate*epoch))

# %% [markdown]
# # Linear regression examples

# %% [markdown]
# ## Plot hypothesis

# %%
import numpy as np
from matplotlib import pyplot as plt

# Columns: population of city, profit
data = np.loadtxt('datasets/food_truck.csv', delimiter=',')

X = data[:, 0:1]
y = data[:, 1:2]

plt.xlabel('Population of City in 10,000s')
plt.ylabel('Profit in $10,000s')
plt.plot(X, y, 'xr')

theta = np.array([[-1], [2]])
min_max = np.array([[np.min(X)], [np.max(X)]])
min_max_with_x0 = np.hstack((np.ones((2,1)), min_max))
pred = min_max_with_x0 @ theta 

plt.plot(min_max, pred)
plt.show()

# %% [markdown]
# ## Plot different hypothesis and mean squared error values

# %%
import numpy as np
from matplotlib import pyplot as plt

data = np.loadtxt('datasets/food_truck.csv', delimiter=',')

m = data.shape[0]
X = np.hstack((np.ones((m, 1)), data[:, 0:1]))
y = data[:, 1:2]

min_max = np.array([[np.min(X[:, 1])], [np.max(X[:, 1])]])
min_max_with_x0 = np.hstack((np.ones((2,1)), min_max))

plt.xlabel('Population of City in 10,000s')
plt.ylabel('Profit in $10,000s')
plt.plot(X[:, 1:2], y, 'xr')

thetas = np.array([
    [[-1], [2]],
    [[-4], [1]],
    [[-13], [1]]
])

for theta in thetas:
    J = mean_squared_error(X, y, theta)
    pred = min_max_with_x0 @ theta
    label = f"J={np.around(J, 2)}"
    plt.plot(min_max, pred, label=label)

plt.legend()
plt.show()

# %% [markdown]
# ## Plot mean squared error for univariable hypothesis

# %%
import numpy as np
from matplotlib import pyplot as plt

data = np.loadtxt('datasets/food_truck.csv', delimiter=',')

X = data[:, 0:1]
y = data[:, 1:2]

theta_vals = np.arange(-7.5,9.25,0.1)
J_vals = []

for theta in theta_vals:
    theta = np.array([[theta]])
    J = mean_squared_error(X, y, theta)
    J_vals.append(J)

plt.xlabel(r'$\theta$')
plt.ylabel(r'$J(\theta)$')
plt.plot(theta_vals, J_vals)
plt.show()

# %% [markdown]
# ## Plot mean squared error for multivariable hypothesis

# %%
 import numpy as np
from matplotlib import pyplot as plt

data = np.loadtxt('datasets/food_truck.csv', delimiter=',')

m = data.shape[0]
X = np.hstack((np.ones((m, 1)), data[:, 0:1]))
y = data[:, 1:2]

# Plotting cost function.

theta0_vals = np.arange(-10, 10,0.1)
theta1_vals = np.arange(-1, 4, 0.1)

J_vals = np.empty((0,len(theta0_vals)))

for theta1 in theta1_vals:
    J_vals_for_theta1 = np.array([])
    
    for theta0 in theta0_vals:
        theta = np.array([[theta0],[theta1]])
        J = mean_squared_error(X, y, theta)
        J_vals_for_theta1 = np.append(J_vals_for_theta1, J)
       
    J_vals = np.append(J_vals, np.array([J_vals_for_theta1]), axis=0)

theta0_grid, theta1_grid = np.meshgrid(theta0_vals, theta1_vals)
 
ax = plt.axes(projection='3d')
ax.set_xlabel(r'$\theta_0$')
ax.set_ylabel(r'$\theta_1$')
ax.set_zlabel(r'$J(\theta)$');
ax.plot_surface(theta0_grid, theta1_grid, J_vals, rstride=1, cstride=1, cmap='viridis', edgecolor='none')
plt.show()

# Plotting cost function for each iteration using contour plot.

plt.contour(theta0_grid, theta1_grid, J_vals, 20)
plt.show()

# %% [markdown]
# ## Plot cost function for univariable hypothesis

# %%
import numpy as np
from matplotlib import pyplot as plt

data = np.loadtxt('datasets/food_truck.csv', delimiter=',')

X = data[:, 0:1]
y = data[:, 1:2]

# Plotting cost function.

theta_vals = np.arange(-7.5,9.25,0.1)
J_vals = []

for theta in theta_vals:
    theta = np.array([[theta]])
    J = mean_squared_error(X, y, theta)
    J_vals.append(J)

plt.xlabel(r'$\theta$')
plt.ylabel(r'$J(\theta)$')
plt.plot(theta_vals, J_vals)

# Plotting cost function for each iteration.

num_iterations = 5
alpha = 0.004
theta = np.array([[-7.5]])

for iteration in range(num_iterations):
    J = mean_squared_error(X, y, theta)
    
    plt.scatter(theta, J, c='green')
    plt.annotate(
        iteration,
        xy=(theta, J),
        xytext=(theta+1, J+200),
        arrowprops=dict(arrowstyle='->')
    )
    
    theta = gradient_descent(X, y, theta, alpha)
    
plt.ylim(0, 3200)
plt.show()

# %% [markdown]
# ## Plot cost function for multivariable hypothesis

# %%
import numpy as np
from matplotlib import pyplot as plt

data = np.loadtxt('datasets/food_truck.csv', delimiter=',')

m = data.shape[0]
X = np.hstack((np.ones((m, 1)), data[:, 0:1]))
y = data[:, 1:2]

# Plotting cost function.

theta0_vals = np.arange(-10, 10,0.1)
theta1_vals = np.arange(-1, 4, 0.1)

J_vals = np.empty((0,len(theta0_vals)))

for theta1 in theta1_vals:
    J_vals_for_theta1 = np.array([])
    
    for theta0 in theta0_vals:
        theta = np.array([[theta0],[theta1]])
        J = mean_squared_error(X, y, theta)
        J_vals_for_theta1 = np.append(J_vals_for_theta1, J)
       
    J_vals = np.append(J_vals, np.array([J_vals_for_theta1]), axis=0)

theta0_grid, theta1_grid = np.meshgrid(theta0_vals, theta1_vals)
 
ax = plt.axes(projection='3d')
ax.set_xlabel(r'$\theta_0$')
ax.set_ylabel(r'$\theta_1$')
ax.set_zlabel(r'$J(\theta)$');
ax.plot_surface(theta0_grid, theta1_grid, J_vals, rstride=1, cstride=1, cmap='viridis', edgecolor='none')

# Plotting cost function for each iteration.

num_iterations = 5
alpha = 0.004
theta = np.array([[7], [3]])

for iteration in range(num_iterations):
    J = mean_squared_error(X, y, theta)
    ax.scatter3D(theta[0], theta[1], J,  c='blue');
    theta = gradient_descent(X, y, theta, alpha)

plt.show()

# Plotting cost function for each iteration using contour plot.
plt.xlabel(r'$\theta_0$')
plt.ylabel(r'$\theta_1$')
plt.contour(theta0_grid, theta1_grid, J_vals, 20)

num_iterations = 5
alpha = 0.005
theta = np.array([[0], [3.5]])

for iteration in range(num_iterations):
    J = mean_squared_error(X, y, theta)
    plt.scatter(theta[0], theta[1],  c='blue');
    theta = gradient_descent(X, y, theta, alpha)
    
plt.show()

# %% [markdown]
# ## Plot cost function for different learning rates I

# %%
import numpy as np
from matplotlib import pyplot as plt

data = np.loadtxt('datasets/food_truck.csv', delimiter=',')

X = data[:, 0:1]
y = data[:, 1:2]

# Plotting cost function.

theta_vals = np.arange(-6,8,0.1)
J_vals = []

for theta in theta_vals:
    theta = np.array([[theta]])
    J = mean_squared_error(X, y, theta)
    J_vals.append(J)

# Plotting cost function for each iteration.

plt.figure(figsize=(16, 4))

num_iterations = 5
alphas = [0.001, 0.005, 0.025]

for index, alpha in enumerate(alphas):
    plt.subplot(1, 3, index + 1)
    plt.title(r'$\alpha = $' + str(alpha))
    plt.xlabel(r'$\theta$')
    plt.ylabel(r'$J(\theta)$')
    plt.plot(theta_vals, J_vals)
    
    theta = np.array([[-5]])
                   
    for iteration in range(num_iterations):
        J = mean_squared_error(X, y, theta)

        plt.scatter(theta, J, c='green')
        plt.annotate(
            iteration,
            xy=(theta, J),
            xytext=(theta+1, J+200),
            arrowprops=dict(arrowstyle='->')
        )

        theta = gradient_descent(X, y, theta, alpha)

plt.show()

# %% [markdown]
# ## Plot cost function for differen learning rates II

# %%
import numpy as np
from matplotlib import pyplot as plt

data = np.loadtxt('datasets/food_truck.csv', delimiter=',')

X = data[:, 0:1]
y = data[:, 1:2]

# Plotting cost function.

theta_vals = np.arange(-6,8,0.1)
J_vals = []

for theta in theta_vals:
    theta = np.array([[theta]])
    J = mean_squared_error(X, y, theta)
    J_vals.append(J)

# Plotting cost function for each iteration.

plt.figure(figsize=(16, 4))

num_iterations = 20
alphas = [0.001, 0.005, 0.025]

for index, alpha in enumerate(alphas):
    plt.subplot(1, 3, index + 1)
    plt.ylim(0, 3200)
    plt.title(r'$\alpha = $' + str(alpha))
    plt.xlabel('epochs')
    plt.ylabel(r'$J(\theta)$')
 
    theta = np.array([[-5]])
    J_hist = np.array([])
                   
    for iteration in range(num_iterations):
        J = mean_squared_error(X, y, theta)        
        J_hist = np.append(J_hist, J)
        theta = gradient_descent(X, y, theta, alpha)
    
    plt.plot(J_hist, c='blue')

plt.show()

# %% [markdown]
# ## Plot hypothesis and cost function

# %%
import numpy as np
from matplotlib import pyplot as plt

data = np.loadtxt('datasets/food_truck.csv', delimiter=',')

m = data.shape[0]
X = np.hstack((np.ones((m, 1)), data[:, 0:1]))
y = data[:, 1:2]

num_iterations = 5
alpha = 0.005
theta = np.array([[-2], [-0.5]])

plt.figure(figsize=(16, 8))

# Plot hypothesis for each iteration.
min_max = np.array([[np.min(X[:, 1])], [np.max(X[:, 1])]])
min_max_with_x0 = np.hstack((np.ones((2,1)), min_max))

plt.xlabel('Population of City in 10,000s')
plt.ylabel('Profit in $10,000s')
plt.plot(X[:, 1:2], y, 'xr')

for epoch in range(num_iterations):
    J = mean_squared_error(X, y, theta)
    pred = min_max_with_x0 @ theta
    label = f"epoch={epoch}, J={np.around(J, 2)}"
    plt.plot(min_max, pred, label=label)
    theta = gradient_descent(X, y, theta, alpha)

plt.legend()
plt.show()

# %% [markdown]
# ## Plot normalized features

# %%
import numpy as np
from matplotlib import pyplot as plt

# Columns: sizeof the house, number of bedrooms, price.
data = np.loadtxt('datasets/house_prices.csv', delimiter=',')

m = data.shape[0]
X = data[:, 0:2]
y = data[:, 2:3]

X_norm, mu, sigma = feature_normalize(X)

plt.figure(figsize=(16, 4))

plt.subplot(1, 2, 1)
plt.title('Original data')
plt.xlabel('House area $[ft^2]$')
plt.ylabel('Number of bedrooms')
plt.plot(X[:, 0], X[:, 1], 'rx')

plt.subplot(1, 2, 2)
plt.title('Normalized data')
plt.xlabel('House area $[ft^2]$')
plt.ylabel('Number of bedrooms')

plt.plot(X_norm[:, 0], X_norm[:, 1], 'rx')

plt.show()

# %% [markdown]
# ## Calculate hypothesis for noralized features

# %%
import numpy as np
from matplotlib import pyplot as plt

# Columns: sizeof the house, number of bedrooms, price.
data = np.loadtxt('datasets/house_prices.csv', delimiter=',')

m = data.shape[0]
X = data[:, 0:2]
y = data[:, 2:3]

X_norm, mu, sigma = feature_normalize(X)
X_norm = np.hstack((np.ones((m, 1)), X_norm[:, 0:2]))

# Plotting cost function for each iteration.

iterations = 800
J_hist = np.array([])
alpha = 0.01
theta = np.array([[0], [0], [0]])

for _ in range(iterations):
    J = mean_squared_error(X_norm, y, theta)
    J_hist = np.append(J_hist, J)
    theta = gradient_descent(X_norm, y, theta, alpha)

plt.xlabel('epochs')
plt.ylabel(r'$J(\theta)$')
plt.plot(J_hist)
plt.show()

# Predicting price for 1650 square feet house with 3 bedrooms.
X = np.array([[1650, 3]])
X_norm = (X - mu) / sigma
X_norm = np.append(1, X_norm)
price = X_norm @ theta
print('Price:', price)
# Out:
# Price: [293346.56303104]

# %% [markdown]
# ## Calculate hypothesis using normal equation

# %%
import numpy as np
from matplotlib import pyplot as plt

# Columns: sizeof the house, number of bedrooms, price.
data = np.loadtxt('datasets/house_prices.csv', delimiter=',')

m = data.shape[0]
X = np.hstack((np.ones((m, 1)), data[:, 0:2]))
y = data[:, 2:3]

# Finding theta for minimum value of cost function.
theta = normal_equation(X, y)

# Predicting price for 1650 square feet house with 3 bedrooms.
x = np.array([[1], [1650], [3]])
price = x.T @ theta
print('Price:', price)
# Out:
# Price: [[293081.46433489]]

# %% [markdown]
# ## Comparing gradient descent with and without learning rate decay

# %%
import numpy as np
from matplotlib import pyplot as plt

# Columns: sizeof the house, number of bedrooms, price.
data = np.loadtxt('datasets/house_prices.csv', delimiter=',')

m = data.shape[0]
X = data[:, 0:2]
y = data[:, 2:3]

X_norm, mu, sigma = feature_normalize(X)
X_norm = np.hstack((np.ones((m, 1)), X_norm[:, 0:2]))

plt.figure(figsize=(16, 8))

# Plotting cost function for each iteration.
iterations = 100
alpha = 0.03
theta = np.array([[0], [0], [0]])
J_hist = np.array([])
alpha_hist = np.full((iterations, 1), alpha)

for _ in range(iterations):
    J = mean_squared_error(X_norm, y, theta)
    J_hist = np.append(J_hist, J)
    theta = gradient_descent(X_norm, y, theta, alpha)

plt.subplot(2, 2, 1)
plt.title("Constant learning rate.")
plt.xlabel('epochs')
plt.ylabel(r'$J(\theta)$')
plt.plot(J_hist)

plt.subplot(2, 2, 3)
plt.xlabel('epochs')
plt.ylabel('learning rate')
plt.plot(alpha_hist)

# Plotting cost function for each iteration using decay learning rate.
iterations = 8
eta = 0.2
decay_rate = 0.25
theta = np.array([[0], [0], [0]])
J_hist = np.array([])
eta_hist = np.array([])

for iteration in range(iterations):
    J = mean_squared_error(X_norm, y, theta)
    J_hist = np.append(J_hist, J)
    eta = decay_learning_rate(eta, decay_rate, iteration)
    eta_hist = np.append(eta_hist, eta)
    theta = gradient_descent(X_norm, y, theta, eta)
    
plt.subplot(2, 2, 2)
plt.title("Decay learning rate.")
plt.xlabel('epochs')
plt.ylabel(r'$J(\theta)$')
plt.plot(J_hist)

plt.subplot(2, 2, 4)
plt.xlabel('epochs')
plt.ylabel('learning rate')
plt.plot(eta_hist)

plt.show()

# %% [markdown]
# ## Plot hypothesis using different functions

# %%
import numpy as np
from matplotlib import pyplot as plt

# Columns: population of city, profit
data = np.loadtxt('datasets/food_truck.csv', delimiter=',')

m = data.shape[0]
X = data[:, 0:1]
y = data[:, 1:2]

X, _, _ = feature_normalize(X)
X = X + np.abs(np.min(X))

plt.figure(figsize=(16, 12))

# Linear function
X_linear = np.hstack((np.ones((m, 1)), X[:, 0:1]))
iterations = 800
alpha = 0.01
theta = np.array([[0], [0]])

for _ in range(iterations):
    theta = gradient_descent(X_linear, y, theta, alpha)

plt.subplot(2, 2, 1)
plt.title(r'$h(\theta)=\theta_0x_0 + \theta_1x_1$')
plt.xlabel('Population of City (normalized)')
plt.ylabel('Profit in $10,000s')
plt.plot(X, y, 'xr')

min_max = np.array([[np.min(X)], [np.max(X)]])
min_max_with_x0 = np.hstack((np.ones((2,1)), min_max))
pred = min_max_with_x0 @ theta 
plt.plot(min_max, pred)

# Quadratic function
X_quadratic = np.hstack((np.ones((X.shape[0], 1)), X, (X * X)))
iterations = 80
alpha = 0.01
theta = np.array([[0], [0], [0]])

for _ in range(iterations):
    theta = gradient_descent(X_quadratic, y, theta, alpha)

plt.subplot(2, 2, 2)
plt.title(r'$h(\theta)=\theta_0x_0 + \theta_1x_1 + \theta_2x_1^2$')
plt.xlabel('Population of City (normalized)')
plt.ylabel('Profit in $10,000s')
plt.plot(X, y, 'xr')

min_max = np.arange(np.min(X), np.max(X), 0.1)[:, np.newaxis]
min_max_with_x0 = np.hstack((np.ones((min_max.shape[0], 1)), min_max, (min_max*min_max)))
pred = min_max_with_x0 @ theta 
plt.plot(min_max, pred)

# Square root function
X_square_root = np.hstack((np.ones((X.shape[0], 1)), X, np.sqrt(X)))
iterations = 20
alpha = 0.01
theta = np.array([[0], [0], [8]])

for _ in range(iterations):
    theta = gradient_descent(X_square_root, y, theta, alpha)

plt.subplot(2, 2, 3)
plt.title(r'$h(\theta)=\theta_0x_0 + \theta_1x_1 + \theta_2\sqrt{x_1}$')
plt.xlabel('Population of City (normalized)')
plt.ylabel('Profit in $10,000s')
plt.plot(X, y, 'xr')

min_max = np.arange(np.min(X), np.max(X), 0.1)[:, np.newaxis]
min_max_with_x0 = np.hstack((np.ones((min_max.shape[0], 1)), min_max, np.sqrt(min_max)))
pred = min_max_with_x0 @ theta 
plt.plot(min_max, pred)

# Polynomial function
X_polynomial = np.hstack((np.ones((X.shape[0], 1)), X, (X * X), (X * X * X)))
iterations = 3000
alpha = 0.001
theta = np.array([[1], [10], [-9], [2]])

for _ in range(iterations):
    theta = gradient_descent(X_polynomial, y, theta, alpha)

plt.subplot(2, 2, 4)
plt.title(r'$h(\theta)=\theta_0x_0 + \theta_1x_1 + \theta_2x_1^2 + \theta_3x_1^3$')
plt.xlabel('Population of City (normalized)')
plt.ylabel('Profit in $10,000s')
plt.plot(X, y, 'xr')

min_max = np.arange(np.min(X), np.max(X), 0.1)[:, np.newaxis]
min_max_with_x0 = np.hstack((np.ones((min_max.shape[0], 1)), min_max, (min_max*min_max), (min_max*min_max*min_max)))
pred = min_max_with_x0 @ theta 
plt.plot(min_max, pred)

plt.show()
